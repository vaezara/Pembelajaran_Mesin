# %%
# !pip install pyprep
# Out:
# ...
#    ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.4 MB ? eta -:--:--
#    ------- -------------------------------- 1.3/7.4 MB 4.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.1/7.4 MB 4.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.1/7.4 MB 4.1 MB/s eta 0:00:02
#    --------------------- ------------------ 3.9/7.4 MB 4.1 MB/s eta 0:00:01
#    ------------------------- -------------- 4.7/7.4 MB 4.2 MB/s eta 0:00:01
#    ------------------------------- -------- 5.8/7.4 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.6/7.4 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  7.3/7.4 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.4/7.4 MB 3.7 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/3 [pooch]
#    ---------------------------------------- 0/3 [pooch]
# ...

# %%
# !pip install scipy

# %%
# !pip install wandb
# Out:
# ...
#    ---------------------------------------- 0.0/21.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/21.6 MB ? eta -:--:--
#    - -------------------------------------- 0.8/21.6 MB 2.0 MB/s eta 0:00:11
#    -- ------------------------------------- 1.3/21.6 MB 2.2 MB/s eta 0:00:10
#    --- ------------------------------------ 2.1/21.6 MB 2.6 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.9/21.6 MB 2.8 MB/s eta 0:00:07
#    ------ --------------------------------- 3.7/21.6 MB 3.0 MB/s eta 0:00:06
#    -------- ------------------------------- 4.7/21.6 MB 3.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 5.8/21.6 MB 3.4 MB/s eta 0:00:05
#    ------------ --------------------------- 6.6/21.6 MB 3.5 MB/s eta 0:00:05
#    -------------- ------------------------- 7.6/21.6 MB 3.7 MB/s eta 0:00:04
# ...

# %%
# !pip install pyECG
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
# ...

# %%
# !pip install git+https://github.com/berndporr/py-ecg-detectors.git
# Out:
# ...
#   Cloning https://github.com/berndporr/py-ecg-detectors.git to c:\users\admin\appdata\local\temp\pip-req-build-2x95e95h
#   Resolved https://github.com/berndporr/py-ecg-detectors.git to commit f39354cb686710f8e243e214b94fda0914fff656
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/554.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/554.5 kB ? eta -:--:--
#      ------------------ --------------------- 262.1/554.5 kB ? eta -:--:--
#      ----------------------------------- -- 524.3/554.5 kB 1.3 MB/s eta 0:00:01
#      ------------------------------------ 554.5/554.5 kB 910.6 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
import pyprep
import scipy
import wandb
from ecgdetectors import Detectors

# %% [markdown]
# KEGUNAAN LIBRARY
# 1. PyPREP : membersihkan data EEG, menghilangkan noise, merapikan dta EEG sebelum dianalisis.
# 2. SciPy : alat matematika, statistik dan sains untuk hitung rumus, uji statistik atau transformasi data.
# 3. wandb : mencatat dan memantau percobaan machine learning dalam grafik training.
# 4. pyECG : menganalisis sinyal jantung

# %% [markdown]
# BAGIAN 2
#
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#    Jawab :  Menggunakan AI untuk membuat gambar, video ataupun artikel hoaks yang dapat menyebabkan kerugian. Referensi : https://kumparan.com/thoriqhkm/disinformasi-digital-ancaman-sosial-dan-politik-di-era-kecerdasan-buatan-25gLr6aFFIv/1
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan
#    pendapat pribadi). Sertakan referensi yang digunakan.
#    Jawab : Dampak yang diberikan dari pemanfaatan AI ialah emisi gas rumah kaca yang disebabkan dari penyimpanan data dan perkembangan AI. Lalu jejak karbon yang ditinggalkan lebih besar karena memerlukan energi yang sangat besar.
